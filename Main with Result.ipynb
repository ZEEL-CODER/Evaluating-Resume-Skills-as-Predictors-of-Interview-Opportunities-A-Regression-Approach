# %% [markdown]
# TEAM MEMBERS: ZEEL DUDHAT (KU2407U064), VASU PATEL (KU2407U752) , NEEL PATEL (KU2407U685), DARSH LORIYA (KU2407U038).

# %%
import pandas as pd

df = pd.read_csv("resume.csv")

print(df.head())        # First 5 rows
print(df.info())        # Data types
print(df.describe())    # Statistics
print(df.isnull().sum()) # Missing values
# Out:
#   candidate_id degree  years_experience  projects_count  certifications  \
# 0         C001  BTech                 0              11               2
# 1         C002  BTech                 8               1               4
# 2         C003    BSc                 3               8               4
# 3         C004    MCA                 4              12               6
# 4         C005  MTech                 2               3               6
#
#    skills_count internship github_portfolio  resume_score  interview_calls
# 0            11        Yes              Yes            89                6
# 1            17        Yes              Yes           100                6
# 2             4        Yes               No            89                4
# 3             4        Yes               No           100                7
# 4            14        Yes              Yes            96                6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# ...

# %%
#visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Correlation heatmap
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# Resume score vs interview calls
sns.scatterplot(x='resume_score', y='interview_calls', data=df)
plt.show()

# %%
#data processing
df = df.drop('candidate_id', axis=1)

# Convert categorical to numeric
df = pd.get_dummies(df, drop_first=True)

# Split data
from sklearn.model_selection import train_test_split

X = df.drop('interview_calls', axis=1)
y = df['interview_calls']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#linear regression
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

print("LR Accuracy:", lr.score(X_test, y_test))

#decision tree
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)

print("DT Accuracy:", dt.score(X_test, y_test))


#randdom forest
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train, y_train)

print("RF Accuracy:", rf.score(X_test, y_test))
# Out:
# LR Accuracy: 0.6716913450446247
# DT Accuracy: 0.3439096531325625
# RF Accuracy: 0.6571110513578919
